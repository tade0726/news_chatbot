# %%
from news_chatbot.datasets import DuckdbNewsDataset
import os

DUCKDB_PATH = os.getenv("DUCKDB_PATH")

dataset = DuckdbNewsDataset(DUCKDB_PATH)

# %%
df = dataset.read_data()

# %%
df
# Out:
#                                                    url  ...  batch_query_time
# 0    https://www.foxsports.com.au/video/afl/afl/cor...  ...        1742713356
# 1    https://www.foxsports.com.au/video/afl/afl/sta...  ...        1742713356
# 2    https://www.foxsports.com.au/video/afl/afl/dog...  ...        1742713356
# 3    https://www.foxsports.com.au/video/afl/afl/kan...  ...        1742713356
# 4    https://www.foxsports.com.au/video/rugby/super...  ...        1742713356
# ..                                                 ...  ...               ...
# 172  https://www.bloomberg.com/news/articles/2025-0...  ...        1742713356
# 173  https://www.bloomberg.com/news/newsletters/202...  ...        1742713356
# 174  https://www.bloomberg.com/news/newsletters/202...  ...        1742713356
# 175  https://www.bloomberg.com/news/newsletters/202...  ...        1742713356
# 176  https://www.dailyliberal.com.au/story/8912148/...  ...        1742713356
#
# [177 rows x 11 columns]

# %%
df[df.topic == "sports"]["title"]
# Out:
# 0     Cornes supports Port succession plan - Fox Sports
# 1     Stars "lucky" after brutal collision - Fox Sports
# 2     Dogs to play as Footscray for milestone - Fox ...
# 3     Kangaroos challenge Archer suspension - Fox Sp...
# 4                        MORE RUGBY VIDEOS - Fox Sports
# 5                        MORE RUGBY VIDEOS - Fox Sports
# 6     Keeffe WINNER leaves MCG heartbroken - Fox Sports
# 7     Keeffe WINNER leaves MCG heartbroken - Fox Sports
# 8     Dogs to play as Footscray for milestone - Fox ...
# 9        Adamant Ken backs succession plan - Fox Sports
# 10    Townsville vs Mackay - QLD Cup Round 2, 2025 -...
# 11                   'This is NOT Sydney!' - Fox Sports
# 12    'That's what you go to the footy to see' - Fox...
# 13    Melbourne Demons vs Greater Western Sydney Gia...
# 14    West Coast Eagles vs Gold Coast Suns - AFL Rou...
# 15                       MORE RUGBY VIDEOS - Fox Sports
# 16                       MORE RUGBY VIDEOS - Fox Sports
# ...
